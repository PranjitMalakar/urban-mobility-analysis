# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


print("Loading dataset...")
df = pd.read_csv("urban_mobility_data.csv")
print("Dataset loaded successfully.")


df['start_time'] = pd.to_datetime(df['start_time'])


df['hour'] = df['start_time'].dt.hour
df['day'] = df['start_time'].dt.day_name()


initial_shape = df.shape
df = df[(df['duration_min'] > 0) & (df['duration_min'] < 180)]
df = df[(df['distance_km'] > 0) & (df['distance_km'] < 100)]
cleaned_shape = df.shape
print(f"Data cleaned: {initial_shape[0]} → {cleaned_shape[0]} records.")


df['speed_kmh'] = df['distance_km'] / (df['duration_min'] / 60)


print("\nSummary statistics:")
print(df[['duration_min', 'distance_km', 'speed_kmh']].describe())


print("\nMissing values in dataset:")
print(df.isnull().sum())



plt.figure(figsize=(10, 5))
df['hour'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title("Trips by Hour of the Day")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Trips")
plt.grid(True)
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 5))
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['day'].value_counts().reindex(day_order).plot(kind='bar', color='coral')
plt.title("Trips by Day of the Week")
plt.xlabel("Day of Week")
plt.ylabel("Number of Trips")
plt.grid(True)
plt.tight_layout()
plt.show()


plt.figure(figsize=(6, 6))
df['mode'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
plt.title("Transport Mode Share")
plt.ylabel("")
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 6))
df.groupby('mode')['speed_kmh'].mean().sort_values().plot(kind='barh', color='mediumseagreen')
plt.title("Average Speed by Mode")
plt.xlabel("Speed (km/h)")
plt.grid(axis='x')
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 6))
df.boxplot(column='duration_min', by='mode', grid=False)
plt.title("Trip Duration by Mode")
plt.suptitle("")
plt.xlabel("Mode of Transport")
plt.ylabel("Duration (minutes)")
plt.tight_layout()
plt.show()

print("\nUrban Mobility Pattern Analysis completed successfully.")
# Out:
# Loading dataset...
# Dataset loaded successfully.
# Data cleaned: 1000 → 1000 records.
#
# Summary statistics:
#        duration_min  distance_km    speed_kmh
# count   1000.000000  1000.000000  1000.000000
# mean      30.899359     6.098624    21.152827
# std       21.042278     4.324691    33.397699
# min        1.000000     0.500000     0.485333
# 25%       15.393170     2.943632     5.684211
# 50%       25.935960     5.178746    11.507319
# 75%       41.132365     7.981841    23.047582
# max      116.803356    40.830698   559.022537
#
# Missing values in dataset:
# start_time        0
# duration_min      0
# distance_km       0
# mode              0
# start_location    0
# end_location      0
# hour              0
# day               0
# speed_kmh         0
# dtype: int64
# Urban Mobility Pattern Analysis completed successfully.
